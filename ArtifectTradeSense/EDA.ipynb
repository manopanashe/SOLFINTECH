# %%
import pandas as pd
from pandas import read_csv
from pandas import set_option
import numpy as np

# %%
df = read_csv('stock_data.csv')
df['Date'] = pd.to_datetime(df['Date'].apply(lambda x: x.split()[0]))
df.set_index('Date',drop=True,inplace=True)
#describing our data
print(df.shape)
print(df.head(5))
# Out:
# (1768, 6)
#               Open    High     Low   Close  Adj Close   Volume
# Date
# 2016-01-04  148.05  148.32  145.40  146.82     118.03  3277200
# 2016-01-05  146.82  147.50  145.61  147.46     118.54  2688100
# 2016-01-06  145.59  145.76  143.42  144.49     116.15  2997100
# 2016-01-07  142.52  143.13  140.63  140.97     113.32  3553500
# 2016-01-08  141.36  142.50  140.22  140.49     112.94  2664000

# %%
# Check data types in columns
print(df.dtypes)
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
# Check for missing values in the columns
print('\n Null Values:\n',df.isna())
# Out:
#  Null Values:
#               Open   High    Low  Close  Adj Close  Volume
# Date
# 2016-01-04  False  False  False  False      False   False
# 2016-01-05  False  False  False  False      False   False
# 2016-01-06  False  False  False  False      False   False
# 2016-01-07  False  False  False  False      False   False
# 2016-01-08  False  False  False  False      False   False
# ...           ...    ...    ...    ...        ...     ...
# 2023-01-04  False  False  False  False      False   False
# 2023-01-05  False  False  False  False      False   False
# 2023-01-06  False  False  False  False      False   False
# 2023-01-09  False  False  False  False      False   False
# 2023-01-10  False  False  False  False      False   False
#
# [1768 rows x 6 columns]

# %%
print('\n Data Statistics \n',df.describe())
# Out:
#  Data Statistics
#            Open     High      Low    Close  Adj Close    Volume
# count  1768.00  1768.00  1768.00  1768.00    1768.00  1.77e+03
# mean    178.59   180.00   177.03   178.55     158.00  2.83e+06
# std      28.13    28.11    28.15    28.14      21.95  2.94e+06
# min     107.50   109.12   107.07   107.52     106.28  6.51e+05
# 25%     161.75   163.11   159.97   161.62     142.75  1.80e+06
# 50%     176.90   177.98   175.57   176.72     156.37  2.25e+06
# 75%     199.49   201.11   197.89   199.54     174.01  3.00e+06
# max     258.51   259.77   255.97   258.63     218.49  5.05e+07

# %%
print('\n The mean value of each variable \n',df.mean())
print('\n The median value of each variable \n',df.median())
# Out:
#  The mean value of each variable
#  Open         1.79e+02
# High         1.80e+02
# Low          1.77e+02
# Close        1.79e+02
# Adj Close    1.58e+02
# Volume       2.83e+06
# dtype: float64
#
#  The median value of each variable
#  Open         1.77e+02
# High         1.78e+02
# Low          1.76e+02
# Close        1.77e+02
# Adj Close    1.56e+02
# Volume       2.25e+06
# dtype: float64

# %%
#Correlation Analysis
import seaborn as sn
pd.set_option('display.width',2000)
pd.set_option('display.precision',2)
data_corr = df.corr(method='pearson')
print('Data Correlation \n',data_corr)
sn.heatmap(data_corr,annot=True)
# Out:
# Data Correlation
#             Open  High   Low  Close  Adj Close  Volume
# Open       1.00  1.00  1.00   1.00       0.93   -0.27
# High       1.00  1.00  1.00   1.00       0.93   -0.26
# Low        1.00  1.00  1.00   1.00       0.93   -0.28
# Close      1.00  1.00  1.00   1.00       0.93   -0.28
# Adj Close  0.93  0.93  0.93   0.93       1.00   -0.22
# Volume    -0.27 -0.26 -0.28  -0.28      -0.22    1.00
# <AxesSubplot: >

# %%
#Skewness check
pd.set_option('display.width',2000)
pd.set_option('display.precision',2)
print('Skewness Check \n',df.skew())
# Out:
# Skewness Check
#  Open         2.20e-02
# High         4.19e-02
# Low         -5.90e-04
# Close        1.91e-02
# Adj Close    9.12e-02
# Volume       9.54e+00
# dtype: float64

# %%
 #Visualising our dataset' data distribution
import matplotlib.pyplot as plt
pd.set_option('display.width',2000)
pd.set_option('display.precision',2)
df.hist(figsize=(12,8))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,4))
ax.plot(df['Open'])
# Set figure title
plt.title('Open Stock Price History [2016 - Present Day]', fontsize=16)
# Set x label
plt.xlabel('Date', fontsize=14)
# Set y label
plt.ylabel('Open Stock Price in $', fontsize=14)
# Rotate and align the x labels
fig.autofmt_xdate()
# Show plot
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,4))
ax.plot(df['High'])
# Set figure title
plt.title('High Stock Price History [2016 - Present Day]', fontsize=16)
# Set x label
plt.xlabel('Date', fontsize=14)
# Set y label
plt.ylabel('High Stock Price in $', fontsize=14)
# Rotate and align the x labels
fig.autofmt_xdate()
# Show plot
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,4))
ax.plot(df['Low'])
# Set figure title
plt.title('Low Stock Price History [2016 - Present Day]', fontsize=16)
# Set x label
plt.xlabel('Date', fontsize=14)
# Set y label
plt.ylabel('Low Stock Price in $', fontsize=14)
# Rotate and align the x labels
fig.autofmt_xdate()
# Show plot
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,4))
ax.plot(df['Close'])
# Set figure title
plt.title('Close Stock Price History [2016 - Present Day]', fontsize=16)
# Set x label
plt.xlabel('Date', fontsize=14)
# Set y label
plt.ylabel('Closing Stock Price in $', fontsize=14)
# Rotate and align the x labels
fig.autofmt_xdate()
# Show plot
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,4))
ax.plot(df['Adj Close'])
# Set figure title
plt.title('Adj Close Stock Price History [2016 - Present Day]', fontsize=16)
# Set x label
plt.xlabel('Date', fontsize=14)
# Set y label
plt.ylabel('Adj Closing Stock Price in $', fontsize=14)
# Rotate and align the x labels
fig.autofmt_xdate()
# Show plot
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,4))
ax.plot(df['Volume'])
# Set figure title
plt.title('Volume of Stock Price History [2016 - Present Day]', fontsize=16)
# Set x label
plt.xlabel('Date', fontsize=14)
# Set y label
plt.ylabel('Volume of  Stock Price in $', fontsize=14)
# Rotate and align the x labels
fig.autofmt_xdate()
# Show plot
plt.show()
